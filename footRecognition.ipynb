# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from keras.optimizers import RMSprop

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = image.load_img("/content/drive/MyDrive/ML/testing/1.jpg")
plt.imshow(img)

# %%
train = ImageDataGenerator(rescale=1/255)
validation  = ImageDataGenerator(rescale=1/255)

# %%
train_dataset = train.flow_from_directory('/content/drive/MyDrive/ML/training', target_size= (200,200), batch_size = 3, class_mode='binary')
validation_dataset = validation.flow_from_directory('/content/drive/MyDrive/ML/validation', target_size= (200,200), batch_size = 3, class_mode='binary')
# Out:
# Found 69 images belonging to 2 classes.
# Found 39 images belonging to 2 classes.

# %%
  dir = os.listdir('/content/ML/validation')
  print(dir)

# %%
file_path = ('path_to_your_main_directory/subdirectory_name')
os.rmdir('/content/ML/validation/.ipynb_checkpoints')

# %%
model = tf.keras.models.Sequential([ tf.keras.layers.Conv2D(16,(3,3), activation='relu', input_shape = (200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32,(3,3), activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64,(3,3), activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    # tf.keras.layers.Conv2D(128,(3,3), activation='relu'),
                                    # tf.keras.layers.MaxPool2D(2,2),
                                    ##
                                    tf.keras.layers.Flatten(),
                                    ##
                                    tf.keras.layers.Dense(512,activation='relu'),
                                    ##
                                    tf.keras.layers.Dense(1,activation='sigmoid')
                                    ])

# %%
model.compile(loss= 'binary_crossentropy',
              optimizer = RMSprop(learning_rate=0.001),
              metrics = ['accuracy'])

# %%
model_fit = model.fit(train_dataset,
                      steps_per_epoch = 3,
                      epochs =10,
                     validation_data = validation_dataset
                      )
# Out:
# Epoch 1/10
# 3/3 [==============================] - 4s 2s/step - loss: 8.2742 - accuracy: 0.6667 - val_loss: 0.7169 - val_accuracy: 0.3947
# Epoch 2/10
# 3/3 [==============================] - 3s 1s/step - loss: 1.3408 - accuracy: 0.6667 - val_loss: 1.3993 - val_accuracy: 0.3947
# Epoch 3/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.4693 - accuracy: 0.8889 - val_loss: 2.1872 - val_accuracy: 0.6053
# Epoch 4/10
# 3/3 [==============================] - 3s 1s/step - loss: 2.1790 - accuracy: 0.4444 - val_loss: 0.5777 - val_accuracy: 0.6053
# Epoch 5/10
# 3/3 [==============================] - 3s 1s/step - loss: 1.8797 - accuracy: 0.6667 - val_loss: 0.7736 - val_accuracy: 0.3947
# Epoch 6/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.6619 - accuracy: 0.5556 - val_loss: 0.6293 - val_accuracy: 0.3947
# Epoch 7/10
# 3/3 [==============================] - 4s 2s/step - loss: 0.7393 - accuracy: 0.4444 - val_loss: 0.7185 - val_accuracy: 0.3947
# Epoch 8/10
# ...

# %%
validation_dataset.class_indices
# Out:
# {'arms': 0, 'legs': 1}

# %%
ndir_path = '/content/drive/MyDrive/ML/testing'

for i in os.listdir(dir_path ):
  img = image.load_img(dir_path+'//'+ i, target_size=(200,200))
  plt.imshow(img)
  plt.show()

  X = image.img_to_array(img)
  X = np.expand_dims(X,axis=0)
  images = np.vstack([X])
  val = model.predict(images)
  if val == 0:
    print("arms")
  else:
    print("legs")
# Out:
# legs
# legs
# legs
# legs
# legs
# legs
# legs
# arms
# arms
# arms
# arms
# arms
# arms

# %%
import pickle

# %%
with open('model_pickle', 'wb') as f:
  pickle.dump("/content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb",f)

# %% [markdown]
# # New Section
